# %%
# %matplotlib notebook

# %%
import matplotlib.pylab as plt
import numpy as np
from math import sqrt
from functools import partial

# %%
x = np.linspace(0, 10)
line, = plt.plot(x, np.sin(x), '--')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
t = np.linspace(-13, 13)
x = 7 * np.cos(t)
y = 5 * np.sin(t)

j, = plt.plot(x, y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def simplepath(a, b):
    x = np.sqrt(a - (a/b) * np.power(y, 2))
    plt.plot(x, y)

# %%
simplepath(3,2)
# Out:
# C:\Users\tinac\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in sqrt
# <img src="data:image/png;base64,..." width="640">

# %%
def ellx(a, b, y):
    try:
        return a * sqrt(1 - (y ** 2) / (b ** 2))
    except:
        return 0

# %%
ellx(3, 2, 1.5)
# Out:
# 1.984313483298443

# %%
y = np.linspace(-3, 3)
x = np.fromiter((ellx(3, 2, xi) for xi in x), x.dtype, count=len(x))
plt.plot(x, y)

# %%
ell32 = partial(ellx, 3, 2)

# %%
vf = np.vectorize(ell32)

# %%
y = np.linspace(-2, 2)
x = vf(y)
plt.plot(x, y)
# Out:
# <img src="data:image/png;base64,..." width="640">
